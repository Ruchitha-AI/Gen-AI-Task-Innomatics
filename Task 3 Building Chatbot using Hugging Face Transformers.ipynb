# %% [markdown]
# 𝐂𝐡𝐚𝐭𝐛𝐨𝐭 𝐔𝐬𝐢𝐧𝐠 𝐇𝐮𝐠𝐠𝐢𝐧𝐠 𝐅𝐚𝐜𝐞(𝐃𝐢𝐚𝐥𝐨𝐆𝐏𝐓)

# %%
# installing transformers
import sys
# !{sys.executable} -m pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (5.4.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from transformers) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2026.3.32)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.27.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: colorama in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from typer->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from typer->transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: anyio in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.6.2.post1)
# Requirement already satisfied: certifi in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.6)
# Requirement already satisfied: idna in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.10)
# Requirement already satisfied: sniffio in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.14.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from rich>=12.3.0->typer->transformers) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\ruchi\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
# installing torch
import sys
# !{sys.executable} -m pip install torch --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (2.11.0+cpu)
# Requirement already satisfied: filelock in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from torch) (75.3.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from torch) (2026.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ruchi\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch) (3.0.2)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\ruchi\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
import torch
print("Torch installed:", torch.__version__)
# Out:
# Torch installed: 2.11.0+cpu

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# Load GPT-2 model
model_name = "gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

print("Chatbot: Hello! I am your AI assistant. How can I help you today?")

while True:
    user_input = input("User: ").lower()

    # Exit condition
    if user_input in ["exit", "quit"]:
        print("Chatbot: Chatbot ends the conversation")
        break

    elif "hello" in user_input:
        print("Chatbot: Hello! Nice to meet you. How can I assist you today?")
        continue

    elif "artificial intelligence" in user_input:
        print("Chatbot: Artificial Intelligence refers to the simulation of human intelligence by machines that can perform tasks such as learning, reasoning, and problem solving.")
        continue

    elif "who created python" in user_input or "python creator" in user_input:
        print("Chatbot: Python was created by Guido van Rossum and released in 1991.")
        continue

    elif "thank you" in user_input or "thanks" in user_input:
        print("Chatbot: You're welcome! Feel free to ask more questions.")
        continue

    else:
        # Prepare prompt
        prompt = f"The following is a conversation with a helpful AI assistant.\nUser: {user_input}\nAssistant:"

        # Tokenize input
        inputs = tokenizer(prompt, return_tensors="pt")

        # Generate response
        outputs = model.generate(
            **inputs,
            max_new_tokens=50,
            pad_token_id=tokenizer.eos_token_id
        )

        # Decode response
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        # Only take the assistant's part
        response = response.split("Assistant:")[-1].strip()

        if response:
            print(f"Chatbot: {response}")
        else:
            print("Chatbot: That's interesting! Tell me more.")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Chatbot: Hello! I am your AI assistant. How can I help you today?
# User:  Hello
# Chatbot: Hello! Nice to meet you. How can I assist you today?
# User:  What is artificial intelligence
# Chatbot: Artificial Intelligence refers to the simulation of human intelligence by machines that can perform tasks such as learning, reasoning, and problem solving.
# User:  who created Python?
# Chatbot: Python was created by Guido van Rossum and released in 1991.
# User:  thank you
# Chatbot: You're welcome! Feel free to ask more questions.
# User:  exit
# Chatbot: Chatbot ends the conversation
